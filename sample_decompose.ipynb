# %%
import emg2mu
sampleroot = '/Users/yahya/Documents/git/emg2mu/emg2mu/sample_data/'
emg = emg2mu.EMG(data=sampleroot+'sample1.mat')

# %%
emg.preprocess()

# %%
emg.run_ica(method='torch')
# Out:
# running ICA for 300 sources
# ....................................................
#
# ..................................................
#
# ..................................................
#
# ..................................................
#
# ..................................................
#
# ................................................
# ICA decomposition is completed

# %%
emg.remove_duplicates()

# %%
emg._raw_spike_train.shape
# Out:
# (165204, 300)

# %%
emg.spike_train.shape
# Out:
# (165204, 116)

# %%
emg.compute_scores()

# %%
emg.sil_score
# Out:
# array([0.96304071, 0.95918125, 0.97985315, 0.97488314, 0.96304417,
#        0.97749597, 0.96441823, 0.95139021, 0.93868226, 0.97985733,
#        0.94884998, 0.95167887, 0.96101451, 0.92904252, 0.95101464,
#        0.93074918, 0.91263252, 0.95172977, 0.95623255, 0.95608115,
#        0.95399767, 0.95315605, 0.87462074, 0.92225999, 0.92411441,
#        0.90312082, 0.94815159, 0.89908999, 0.93677205, 0.93246222,
#        0.94260925, 0.93133706, 0.92611355, 0.94381881, 0.90127885,
#        0.93608958, 0.90604383, 0.93809545, 0.90477473, 0.897084  ,
#        0.95201033, 0.85067958, 0.89567405, 0.94980311, 0.88328224,
#        0.86965746, 0.9230051 , 0.88613325, 0.90668517, 0.85407037,
#        0.90837198, 0.89322501, 0.93968689, 0.92886841, 0.87137443,
#        0.95231724, 0.86188745, 0.83439147, 0.87500954, 0.90974706,
#        0.82809436, 0.93738097, 0.88870674, 0.86287683, 0.887577  ,
#        0.92949671, 0.97013152, 0.92273164, 0.90006775, 0.90916163,
#        0.90779132, 0.94757295, 0.92847759, 0.93368971, 0.90118557,
#        0.93402809, 0.91336465, 0.8810901 , 0.89949697, 0.88517106,
#        0.80937666, 0.88138735, 0.93532157, 0.8902024 , 0.9173916 ,
#        0.86105227, 0.86729687, 0.83036453, 0.97422278, 0.93658996,
#        0.86082923, 0.86533374, 0.88200182, 0.82058054, 0.92549878,
#        0.82220566, 0.7820968 , 0.90790504, 0.93264174, 0.86732113,
#        0.86732805, 0.85454822, 0.87489146, 0.84253836, 0.86643422,
#        0.91298276, 0.8026157 , 0.84894085, 0.85140222, 0.90426248,
#        0.84932643, 0.80285972, 0.82850462, 0.94487059, 0.86549741,
#        0.90669656])

# %%
emg.plot(spike_width=0.01, spike_height=0.4, color_plot=True, colormap='turbo', min_score=0.93)

# %%
a = emg.spike_train[:,emg.sil_score>0.9]

# %%
import importlib
importlib.reload(emg2mu)
# Out:
# <module 'emg2mu' from '/Users/yahya/Documents/git/emg2mu/emg2mu/__init__.py'>
