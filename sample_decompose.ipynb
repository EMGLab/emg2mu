# %%
import emg2mu
sampleroot = '/Users/yahya/Documents/git/emg2mu/emg2mu/sample_data/'
emg = emg2mu.EMG(data=sampleroot+'sample1.mat')

# %%
emg.preprocess()

# %%
emg.run_ica(method='torch')
# Out:
# running ICA for 300 sources
# ....................................................
#
# ..................................................
#
# ..................................................
#
# ..................................................
#
# ..................................................
#
# ................................................
# ICA decomposition is completed

# %%
emg.remove_duplicates()

# %%
emg._raw_spike_train.shape
# Out:
# (165204, 300)

# %%
emg.spike_train.shape
# Out:
# (165204, 69)

# %%
emg.compute_scores()

# %%
emg.sil_score
# Out:
# array([0.98297691, 0.98544753, 0.95446897, 0.97445971, 0.97729194,
#        0.96734649, 0.9781726 , 0.96204156, 0.95340472, 0.90961003,
#        0.94170886, 0.93274426, 0.98266357, 0.91614282, 0.93817163,
#        0.90703923, 0.9120487 , 0.92682105, 0.8867389 , 0.90346211,
#        0.95788425, 0.96014935, 0.89779252, 0.86925572, 0.8975929 ,
#        0.89891809, 0.8546344 , 0.87509561, 0.86047935, 0.95451605,
#        0.89977592, 0.87161314, 0.89958423, 0.94491893, 0.82164544,
#        0.84867483, 0.78463382, 0.93622768, 0.91815346, 0.85464722,
#        0.91414464, 0.91025275, 0.83257353, 0.91747397, 0.81772107,
#        0.90925908, 0.90247852, 0.77220607, 0.90301412, 0.9309423 ,
#        0.83183396, 0.77739686, 0.84154522, 0.85048187, 0.85477048,
#        0.85414171, 0.84806335, 0.83897763, 0.8199029 , 0.91514432,
#        0.89870715, 0.90345347, 0.91076905, 0.96308422, 0.92798829,
#        0.86854666, 0.87466848, 0.85766631, 0.8432743 ])

# %%
emg.plot(spike_width=0.01, spike_height=0.4, color_plot=True, colormap='turbo', min_score=0.93)

# %%
emg.plot(plot_type='waveforms', min_score=0.93)
emg.save()

# %%
import importlib
importlib.reload(emg2mu)
# Out:
# <module 'emg2mu' from '/Users/yahya/Documents/git/emg2mu/emg2mu/__init__.py'>
